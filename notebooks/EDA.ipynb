# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
calls = pd.read_csv('../data/raw/megaline_calls.csv')
internet = pd.read_csv('../data/raw/megaline_internet.csv')
messages = pd.read_csv('../data/raw/megaline_messages.csv')
plans = pd.read_csv('../data/raw/megaline_plans.csv')
users = pd.read_csv('../data/raw/megaline_users.csv')

# %% [markdown]
# # Exploración

# %% [markdown]
# Calls

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
calls.describe()
# Out:
#              user_id       duration
# count  137735.000000  137735.000000
# mean     1247.658046       6.745927
# std       139.416268       5.839241
# min      1000.000000       0.000000
# 25%      1128.000000       1.290000
# 50%      1247.000000       5.980000
# 75%      1365.000000      10.690000
# max      1499.000000      37.600000

# %%
# Registros duplicados exactamente
duplicates = calls.duplicated()
# Duplicadas de llamadas
duplicate_id  = calls["id"].duplicated().sum()
print(f"Numero de duplicados: {duplicates.sum()}")
print(f"Numero de ids duplicados: {duplicate_id.sum()}")
# Out:
# Numero de duplicados: 0
# Numero de ids duplicados: 0

# %% [markdown]
# Internet

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
internet.describe()
# Out:
#              user_id        mb_used
# count  104825.000000  104825.000000
# mean     1242.496361     366.713701
# std       142.053913     277.170542
# min      1000.000000       0.000000
# 25%      1122.000000     136.080000
# 50%      1236.000000     343.980000
# 75%      1367.000000     554.610000
# max      1499.000000    1693.470000

# %%
# Registros duplicados exactamente
duplicates = internet.duplicated()
# Duplicadas de session de internet
duplicate_id  = internet["id"].duplicated().sum()
print(f"Numero de duplicados: {duplicates.sum()}")
print(f"Numero de ids duplicados: {duplicate_id.sum()}")
# Out:
# Numero de duplicados: 0
# Numero de ids duplicados: 0

# %% [markdown]
# Messages

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
messages.describe()
# Out:
#             user_id
# count  76051.000000
# mean    1245.972768
# std      139.843635
# min     1000.000000
# 25%     1123.000000
# 50%     1251.000000
# 75%     1362.000000
# max     1497.000000

# %%
# Registros duplicados exactamente
duplicates = messages.duplicated()
# Duplicadas de session de internet
duplicate_id = messages["id"].duplicated().sum()
print(f"Numero de duplicados: {duplicates.sum()}")
print(f"Numero de ids duplicados: {duplicate_id.sum()}")
# Out:
# Numero de duplicados: 0
# Numero de ids duplicados: 0

# %% [markdown]
# Plans

# %%
plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 260.0+ bytes

# %%
plans.describe()
# Out:
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# std           671.751442           10861.160159       1767.766953
# min            50.000000           15360.000000        500.000000
# 25%           287.500000           19200.000000       1125.000000
# 50%           525.000000           23040.000000       1750.000000
# 75%           762.500000           26880.000000       2375.000000
# max          1000.000000           30720.000000       3000.000000
#
#        usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# count         2.000000     2.00000         2.000000        2.000000
# mean         45.000000     8.50000         0.020000        0.020000
# std          35.355339     2.12132         0.014142        0.014142
# min          20.000000     7.00000         0.010000        0.010000
# ...

# %% [markdown]
# Users

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
users.describe()
# Out:
#            user_id         age
# count   500.000000  500.000000
# mean   1249.500000   45.486000
# std     144.481833   16.972269
# min    1000.000000   18.000000
# 25%    1124.750000   30.000000
# 50%    1249.500000   46.000000
# 75%    1374.250000   61.000000
# max    1499.000000   75.000000

# %%
# Registros duplicados exactamente
duplicates = users.duplicated()
# Duplicadas de session de internet
duplicate_id = users["user_id"].duplicated().sum()
print(f"Numero de duplicados: {duplicates.sum()}")
print(f"Numero de ids duplicados: {duplicate_id.sum()}")
# Out:
# Numero de duplicados: 0
# Numero de ids duplicados: 0

# %% [markdown]
# No tenemos valores ausentes en las bases de datos
#
# No existen registros duplicados exactamente ni duplicados con mismo id u distintos valores
#
# Yeii :)

# %% [markdown]
# # Visualizaciones

# %%
# Convertir fechas a datetime
calls["call_date"] = pd.to_datetime(calls["call_date"])
internet["session_date"] = pd.to_datetime(internet["session_date"])
messages["message_date"] = pd.to_datetime(messages["message_date"])
users["reg_date"] = pd.to_datetime(users["reg_date"])
users["churn_date"] = pd.to_datetime(users["churn_date"])

# 1. Distribución de duración de llamadas
plt.figure(figsize=(8, 5))
sns.histplot(calls["duration"], bins=30, kde=True)
plt.title("Distribución de Duración de Llamadas")
plt.xlabel("Duración (min)")
plt.ylabel("Frecuencia")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=calls["duration"])
plt.title("Boxplot de Duración de Llamadas")
plt.xlabel("Duración (min)")
plt.show()

# %%
# 2. Distribución de consumo de datos
plt.figure(figsize=(8, 5))
sns.histplot(internet["mb_used"], bins=30, kde=True)
plt.title("Distribución de Consumo de Datos")
plt.xlabel("MB Usados")
plt.ylabel("Frecuencia")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=internet["mb_used"])
plt.title("Boxplot de Consumo de Datos")
plt.xlabel("MB Usados")
plt.show()

# %% [markdown]
# MB usados en parecido a la duracion en minutos

# %%
# 3. Cantidad de mensajes enviados por usuario
messages_per_user = messages["user_id"].value_counts()
plt.figure(figsize=(8, 5))
sns.histplot(messages_per_user, bins=30, kde=True)
plt.title("Distribución de Mensajes Enviados por Usuario")
plt.xlabel("Cantidad de Mensajes")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Se notan posibles outliers mayores a 1000, hay algunos usuarios que textean muchisimo

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=messages_per_user)
plt.title("Boxplot de Mensajes Enviados por Usuario")
plt.xlabel("Cantidad de Mensajes")
plt.show()

# %% [markdown]
# Valores extremos de cantidad de mensajes mayores a 1000

# %%
plt.figure(figsize=(8, 5))
sns.histplot(users["age"], bins=20, kde=True)
plt.title("Distribución de Edad de los Usuarios")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %%
# 5. Usuarios por ciudad
plt.figure(figsize=(10, 5))
users["city"].value_counts().nlargest(10).plot(kind='bar')
plt.title("Top 10 Ciudades con Más Usuarios")
plt.xlabel("Ciudad")
plt.ylabel("Cantidad de Usuarios")
plt.xticks(rotation=45)
plt.show()

# %%
# 6. Comparación de planes
plt.figure(figsize=(6, 4))
sns.barplot(x=plans["plan_name"], y=plans["usd_monthly_pay"])
plt.title("Costo Mensual por Plan")
plt.xlabel("Plan")
plt.ylabel("Costo Mensual ($)")
plt.show()
